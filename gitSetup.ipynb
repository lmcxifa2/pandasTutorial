# %% [markdown]
# github setup
# Create a new repository in GitHub. Note: Do not initialize the repository with README, .gitignore or license file.

# %% [markdown]
# local git setup

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# change directory
# %cd /content/drive/MyDrive/git/pandasTutorial/
# Out:
# /content/drive/MyDrive/git/pandasTutorial

# %%
# !git init
# !git config --global user.email "lmcxifa2@gmail.com"
# !git config --global user.name "bob"

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git add . 
# !git commit -m "new version"
# Out:
# [master (root-commit) de25dc2] new version
#  1 file changed, 1 insertion(+)
#  create mode 100644 gitSetup.ipynb

# %% [markdown]
# https://neptune.ai/blog/google-colab-dealing-with-files
#
# https://medium.com/analytics-vidhya/how-to-use-google-colab-with-github-via-google-drive-68efb23a42d
#
# * from google drive, right click a jupyter notebook >> open with google colab
